# %%
MyPassword = 'Fluffernutter'
# %store MyPassword
del MyPassword
# Out:
# Stored 'MyPassword' (str)

# %% [markdown]
# In the second jupyter notebook:

# %%
# %store -r MyPassword

# %%
print(MyPassword)
# Out:
# Fluffernutter
